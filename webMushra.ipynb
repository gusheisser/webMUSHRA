# %% [markdown]
# # Designing MUSRHA Tests using webMUSHRA and PyMUSHRA

# %%
# @title
# %%html
<iframe width="900" height="630" src="https://www.youtube.com/embed/ntZqaiAQWr0?si=u8yTyq6mFet-on3A" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="900" height="630" src="https://www.youtube.com/embed/ntZqaiAQWr0?si=u8yTyq6mFet-on3A" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ## Installing webMUSHRA anb PyMUSHRA

# %%
# !mkdir db
# !git clone https://github.com/audiolabs/webMUSHRA.git webmushra
# !git clone https://github.com/nils-werner/pymushra.git pymushra

# !pip install -e pymushra
# Out:
# Cloning into 'webmushra'...
# remote: Enumerating objects: 983, done.
# remote: Counting objects: 100% (319/319), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 983 (delta 271), reused 261 (delta 261), pack-reused 664 (from 1)
# Receiving objects: 100% (983/983), 7.18 MiB | 15.77 MiB/s, done.
# Resolving deltas: 100% (473/473), done.
# Cloning into 'pymushra'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 122 (delta 22), reused 32 (delta 14), pack-reused 75 (from 1)
# Receiving objects: 100% (122/122), 205.98 KiB | 3.75 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# Obtaining file:///content/pymushra
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (8.3.0)
# Requirement already satisfied: flask>=2.2.5 in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (3.1.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (7.34.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (2.2.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (1.16.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (0.13.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from pymushra==0.4) (0.14.5)
# Collecting tinydb>=3.0.0 (from pymushra==0.4)
#   Downloading tinydb-4.8.2-py3-none-any.whl.metadata (6.7 kB)
# Collecting tinyrecord (from pymushra==0.4)
#   Downloading tinyrecord-0.2.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask>=2.2.5->pymushra==0.4) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask>=2.2.5->pymushra==0.4) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask>=2.2.5->pymushra==0.4) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask>=2.2.5->pymushra==0.4) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask>=2.2.5->pymushra==0.4) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pymushra==0.4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pymushra==0.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pymushra==0.4) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pymushra==0.4) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pymushra==0.4) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pymushra==0.4) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pymushra==0.4) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pymushra==0.4) (2.9.0.post0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->pymushra==0.4) (75.2.0)
# Collecting jedi>=0.16 (from ipython->pymushra==0.4)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->pymushra==0.4) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->pymushra==0.4) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->pymushra==0.4) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->pymushra==0.4) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->pymushra==0.4) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->pymushra==0.4) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->pymushra==0.4) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->pymushra==0.4) (4.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pymushra==0.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pymushra==0.4) (2025.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->pymushra==0.4) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->pymushra==0.4) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->pymushra==0.4) (0.2.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pymushra==0.4) (1.17.0)
# Downloading tinydb-4.8.2-py3-none-any.whl (24 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.6 MB/s eta 0:00:00
# Building wheels for collected packages: pymushra, tinyrecord
#   Building editable for pymushra (pyproject.toml) ... done
#   Created wheel for pymushra: filename=pymushra-0.4-py3-none-any.whl size=2702 sha256=2d06607390035fb0cc2a4dbe3bc194c682d83c88115d9d5dd8aedf252b468d3f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nf_wh4c5/wheels/96/7a/b4/31482717b1974651ed1a23c24ea946fc1e1921e621a53c3379
#   Building wheel for tinyrecord (setup.py) ... done
#   Created wheel for tinyrecord: filename=tinyrecord-0.2.0-py3-none-any.whl size=5903 sha256=8144f78d9c8dbeeadc78b72ac329b6f464a7fe6c851d054114c910c9c6f92b0a
#   Stored in directory: /root/.cache/pip/wheels/85/d6/a0/cf91422eb02a0af5c5bac5b18ce906ff999635e23ddc366cf7
# Successfully built pymushra tinyrecord
# Installing collected packages: tinyrecord, tinydb, jedi, pymushra
# Successfully installed jedi-0.19.2 pymushra-0.4 tinydb-4.8.2 tinyrecord-0.2.0

# %% [markdown]
# Schoeffler, M. et al., (2018). webMUSHRA — A Comprehensive Framework for Web-based Listening Tests. Journal of Open Research Software. 6(1), p.8.

# %% [markdown]
# ## Installing and Configuring HTTP Tunneling using Ngrok

# %%
# @title
# %%html
<iframe width="560" height="315" src="https://www.youtube.com/embed/KPHjjHJyUno?si=8ABjFm-EzYQctIM3" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/KPHjjHJyUno?si=8ABjFm-EzYQctIM3" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
# Install PyNgrok
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.4.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Downloading pyngrok-7.4.1-py3-none-any.whl (25 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.4.1

# %%
# Configure Ngrok and Setup Tunneling
from pyngrok import ngrok
ngrok.set_auth_token("35U2owVEr07SVSuP97phlFRr9eR_jwiuU8GKdgvQd58hvLpQ")
public_url = ngrok.connect(5000)
public_url.public_url += "/admin"

# %%
# Print Public URL and start webMUSHRA application
print(public_url)
# !pymushra server
# Out:
# NgrokTunnel: "https://statutory-overdaintily-pamella.ngrok-free.dev/admin" -> "http://localhost:5000"
#  * Serving Flask app 'pymushra.service'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (inotify)
#  * Debugger is active!
#  * Debugger PIN: 493-945-629
# 127.0.0.1 - - [14/Nov/2025 20:07:06] "GET /admin HTTP/1.1" 308 -
# []
# 127.0.0.1 - - [14/Nov/2025 20:07:06] "GET /admin/ HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 20:07:07] "GET /favicon.ico HTTP/1.1" 200 -

# %%
# Kill ngrok tunnel when it's done.
ngrok.kill()

# %% [markdown]
# ## Configuring a webMUSHRA Listening Test

# %%
# @title
# %%html
<iframe width="560" height="315" src="https://www.youtube.com/embed/T7sRhb6iw3Y?si=Scjx-R3G36W1oqtt" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/T7sRhb6iw3Y?si=Scjx-R3G36W1oqtt" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ### Get your audio files into 'webmushra/configs/resources/audio/'

# %%
# Getting some wavefiles
import torchaudio
yesno_data = torchaudio.datasets.YESNO('.', download=True)

# %%
# Move some audio files to the appropriate folder
import pathlib
import shutil
files_list = list(pathlib.Path('/content/waves_yesno/').glob('*.wav'))
for file in files_list[:4]:
  shutil.copy(file, pathlib.Path('/content/webmushra/configs/resources/audio/') / file.name)

# %% [markdown]
# ## Create your Test Configuration File

# %% [markdown]
# ## Read results as Pandas DataFrame

# %%
# @title
# %%html
<iframe width="560" height="315" src="https://www.youtube.com/embed/9_ZBWYOTG9o?si=tYCFwp_lRW4mz43c" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/9_ZBWYOTG9o?si=tYCFwp_lRW4mz43c" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
from pymushra.pymushra import collection_to_df

# %%
from tinydb import TinyDB
db = TinyDB("/content/db/webmushra.json")
print(db.tables())
df = collection_to_df(db.table("mushra_withloop_5"))
df.head()
# Out:
# {'mushra_withloop_5', 'mushra_noloop', 'mushra_nowav'}
#                wm                             \
#                id                       date
# 0  trial_myMushra 2024-07-25 10:24:08.925649
# 1  trial_myMushra 2024-07-25 10:24:08.925649
# 2  trial_myMushra 2024-07-25 10:24:08.925649
# 3  trial_myMushra 2024-07-25 10:24:08.925649
# 4  trial_myMushra 2024-07-25 10:24:08.925649
#
#                            questionaire responses        \
#                                    uuid   comment score
# 0  47d39339-2aea-4c5b-96b5-bb2ff4bb796b      None    69
# 1  47d39339-2aea-4c5b-96b5-bb2ff4bb796b      None   100
# 2  47d39339-2aea-4c5b-96b5-bb2ff4bb796b      None   100
# 3  47d39339-2aea-4c5b-96b5-bb2ff4bb796b      None    59
# 4  47d39339-2aea-4c5b-96b5-bb2ff4bb796b      None   100
#
#                        wm                    responses      wm  responses
#                    config             testId      time    type   stimulus
# 0  configs/myNewTest.yaml  mushra_withloop_5     41015  mushra         C2
# 1  configs/myNewTest.yaml  mushra_withloop_5     41015  mushra  reference
# 2  configs/myNewTest.yaml  mushra_withloop_5     41015  mushra   anchor70
# 3  configs/myNewTest.yaml  mushra_withloop_5     41015  mushra         C1
# 4  configs/myNewTest.yaml  mushra_withloop_5     41015  mushra         C3

# %%
# @title
# %%html
<iframe src="https://www.audiolabs-erlangen.de/resources/webMUSHRA" height="400" width="900" title="Iframe Example"></iframe>
# Out:
# <iframe src="https://www.audiolabs-erlangen.de/resources/webMUSHRA" height="400" width="900" title="Iframe Example"></iframe>
